# %% [markdown]
# <b>Name of experiment = Mini project Using Mechanical Engineering Application Dataset.</b>*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
print(df['Fuel_Type'].unique())
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()
df['Fuel_Type'] = labelencoder.fit_transform(df['Fuel_Type'])

# %%
print(df['Fuel_Type'].unique())
# Out:
# [2 1 0]

# %%
print(df['Fuel_Type'].value_counts())
# Out:
# Fuel_Type
# 2    239
# 1     60
# 0      2
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    int32
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int32(1), int64(3), object(3)
# memory usage: 20.1+ KB

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          2
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          2
# 3  wagon r  2011           2.85           4.15        5200          2
# 4    swift  2014           4.60           6.87       42450          1
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
enc = OneHotEncoder(handle_unknown='ignore')
df['Seller_Type'] = enc.fit_transform(df[['Seller_Type']]).toarray()

# %%
df['Seller_Type'].value_counts()
# Out:
# Seller_Type
# 1.0    195
# 0.0    106
# Name: count, dtype: int64

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          2
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          2
# 3    wagon r  2011           2.85           4.15        5200          2
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          2
# 298     city  2009           3.35          11.00       87934          2
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          2
#
#      Seller_Type Transmission  Owner
# 0            1.0       Manual      0
# ...

# %%
df['Transmission_Num'] = df['Transmission'].map({'Manual': 0, 'Automatic': 1})

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          2
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          2
# 3    wagon r  2011           2.85           4.15        5200          2
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          2
# 298     city  2009           3.35          11.00       87934          2
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          2
#
#      Seller_Type Transmission  Owner  Transmission_Num
# ...

# %%
df.isna().sum()
# Out:
# Car_Name            0
# Year                0
# Selling_Price       0
# Present_Price       0
# Kms_Driven          0
# Fuel_Type           0
# Seller_Type         0
# Transmission        0
# Owner               0
# Transmission_Num    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Car_Name            0
# Year                0
# Selling_Price       0
# Present_Price       0
# Kms_Driven          0
# Fuel_Type           0
# Seller_Type         0
# Transmission        0
# Owner               0
# Transmission_Num    0
# dtype: int64

# %%
df.dtypes
# Out:
# Car_Name             object
# Year                  int64
# Selling_Price       float64
# Present_Price       float64
# Kms_Driven            int64
# Fuel_Type             int32
# Seller_Type         float64
# Transmission         object
# Owner                 int64
# Transmission_Num      int64
# dtype: object

# %%
df['Car_age'] = 2020 - df['Year']

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          2
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          2
# 3    wagon r  2011           2.85           4.15        5200          2
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          2
# 298     city  2009           3.35          11.00       87934          2
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          2
#
#      Seller_Type Transmission  Owner  Transmission_Num  Car_age
# ...

# %%
df.drop(['Year'], axis=1, inplace=True)

# %%
df
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz           3.35           5.59       27000          2
# 1        sx4           4.75           9.54       43000          1
# 2       ciaz           7.25           9.85        6900          2
# 3    wagon r           2.85           4.15        5200          2
# 4      swift           4.60           6.87       42450          1
# ..       ...            ...            ...         ...        ...
# 296     city           9.50          11.60       33988          1
# 297     brio           4.00           5.90       60000          2
# 298     city           3.35          11.00       87934          2
# 299     city          11.50          12.50        9000          1
# 300     brio           5.30           5.90        5464          2
#
#      Seller_Type Transmission  Owner  Transmission_Num  Car_age
# 0            1.0       Manual      0                 0        6
# ...

# %%
df.drop(['Car_Name'], axis=1, inplace=True)

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2          1.0
# 1             4.75           9.54       43000          1          1.0
# 2             7.25           9.85        6900          2          1.0
# 3             2.85           4.15        5200          2          1.0
# 4             4.60           6.87       42450          1          1.0
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          1          1.0
# 297           4.00           5.90       60000          2          1.0
# 298           3.35          11.00       87934          2          1.0
# 299          11.50          12.50        9000          1          1.0
# 300           5.30           5.90        5464          2          1.0
#
#     Transmission  Owner  Transmission_Num  Car_age
# 0         Manual      0                 0        6
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.corr(numeric_only=True)
# Out:
#                   Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# Selling_Price          1.000000       0.878983    0.029187  -0.509467
# Present_Price          0.878983       1.000000    0.203647  -0.440415
# Kms_Driven             0.029187       0.203647    1.000000  -0.166801
# Fuel_Type             -0.509467      -0.440415   -0.166801   1.000000
# Seller_Type            0.550724       0.512030    0.101419  -0.352415
# Owner                 -0.088344       0.008057    0.089216   0.055705
# Transmission_Num       0.367128       0.348715    0.162510  -0.080466
# Car_age               -0.236141       0.047584    0.524342   0.053643
#
#                   Seller_Type     Owner  Transmission_Num   Car_age
# Selling_Price        0.550724 -0.088344          0.367128 -0.236141
# Present_Price        0.512030  0.008057          0.348715  0.047584
# Kms_Driven           0.101419  0.089216          0.162510  0.524342
# ...

# %%
plt.figure(figsize=[17, 5])
plt.subplot(1, 3, 1)
sns.barplot(x='Seller_Type', y='Selling_Price',data=df)
plt.title('Selling Price Vs Seller Type')
# Out:
# Text(0.5, 1.0, 'Selling Price Vs Seller Type')

# %%
plt.subplot(1, 3, 2)
sns.barplot(x='Transmission', y='Selling_Price',data=df)
plt.title('Selling Price Vs Transmission')
# Out:
# Text(0.5, 1.0, 'Selling Price Vs Transmission')

# %%
plt.figure(figsize=(17, 5))
plt.subplot(1, 3, 1)
sns.barplot(x='Owner', y='Selling_Price',data=df)
# Out:
# <Axes: xlabel='Owner', ylabel='Selling_Price'>

# %%
plt.subplot(1, 3, 2)
sns.barplot(x='Car_age', y='Selling_Price',data=df)
# Out:
# <Axes: xlabel='Car_age', ylabel='Selling_Price'>

# %%
plt.subplot(1, 3, 3)
sns.regplot(x='Kms_Driven', y='Selling_Price',data=df)
# Out:
# <Axes: xlabel='Kms_Driven', ylabel='Selling_Price'>

# %%
plt.show()

# %%
plt.figure(figsize=(17, 5))
plt.subplot(1, 3, 1)
sns.barplot(x='Owner', y='Selling_Price',data=df)
plt.title('Selling Price vs Owner')
# Out:
# Text(0.5, 1.0, 'Selling Price vs Owner')

# %%
plt.subplot(1, 3, 2)
sns.barplot(x='Car_age', y='Selling_Price',data=df)
plt.title('Selling Price vs Car age')
# Out:
# Text(0.5, 1.0, 'Selling Price vs Car age')

# %%
plt.subplot(1, 3, 3)
sns.scatterplot(x='Kms_Driven', y='Selling_Price',data=df)
plt.xlabel('Kms_Driven')
plt.ylabel('Selling Price')
plt.title('Selling Price vs kms_driven')
# Out:
# Text(0.5, 1.0, 'Selling Price vs kms_driven')

# %%
# Option 1: Replace infinity with a large finite value (e.g., 1e10)
df_filtered = df.replace([np.inf, -np.inf], 1e10)  # Replace both positive and negative infinity
sns.displot(data=df_filtered, x=np.log(df_filtered['Selling_Price']), kind="hist")
sns.displot(data=df_filtered, x=np.log(df_filtered['Kms_Driven']), kind="hist")

# Option 2: Remove rows with infinity values (if appropriate)
df_filtered = df.dropna(subset=['Selling_Price', 'Kms_Driven'])  # Drop rows with NaN in these columns
sns.displot(data=df_filtered, x=np.log(df_filtered['Selling_Price']), kind="hist")
sns.displot(data=df_filtered, x=np.log(df_filtered['Kms_Driven']), kind="hist")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.show()

# %%
plt.title("Kilometered Drived")
plt.show()

# %%
sns.pairplot(df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
X = df.iloc[:, 1:]
y = df.iloc[:, 0]

# %%
x
# Out:
# array([0.1, 0.3, 0.6, 0.8])

# %%
y
# Out:
# array([0.72, 1.81, 2.73, 3.47])

# %% [markdown]
# **Conclusion: This code is a common preprocessing step when preparing data for machine learning tasks. It separates the features (independent variables) from the target variable (dependent variable), which is necessary for training and evaluating machine learning models.**
